# %%
import json

# %%
pip install google-api-python-client

# %%
pip install oauth2client

# %%
pip install oauth2client==1.5.2

# %%
pip install pyopenssl

# %%
from httplib2 import Http
from oauth2client.client import SignedJwtAssertionCredentials
from apiclient.discovery import build

# %% [markdown]
# #### START

# %%
import json

# %%
import sys
print("User Current Version:-", sys.version)

# %%
pip install oauth2client==4.1.3

# %%
pip install --upgrade google-api-python-client

# %%
#Load Libraries
from oauth2client.service_account import ServiceAccountCredentials
from googleapiclient.discovery import build
import httplib2

# %%
client_email="gs-app-install-api-client@warehousenow-reports-api.iam.gserviceaccount.com"

# %%
cloud_storage_bucket = gs://pubsite_prod_6865168614253693877/stats/installs/

# %%
json_file = 'path_to_json_file_obtained_when_creating_the_service_account'

cloud_storage_bucket = 'pubsite_prod_rev_…'

report_to_download = ‘earnings/earnings_….zip’

# %%
client_email = 'arvindharidas008@gmail.com'
