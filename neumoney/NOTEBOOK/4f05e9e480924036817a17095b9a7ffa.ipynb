# %%
import s3obj

# %%
file_prefix_json = "testing-dataset/test_scinatic_JSON.json"

json_data = s3obj.readJSON(file_prefix_json)
stud_obj = json.loads(json_data['data'])

# %%
def readJSON(self, file_prefix):
        """
        Reads a JSON file with the specified file_prefix from the S3 bucket. 
        Returns a dictionary of the format {"data": {..json data read from s3 file}, "status": "ok|FileNotFound|error|..."}
        """
        resp = {"data":None, "status":None}
        try:
            if self.existS3Key(file_prefix):
                result = self.s3client.get_object(Bucket=self.bucket_name, Key=file_prefix)
                if not result:
                    raise Exception("ReadError")
                jsonbody = result.get("Body").read().decode()
                if not jsonbody:
                    raise Exception("EmptyJson")
                resp = {"data":jsonbody, "status":"ok"}
            else:
                raise Exception("FileNotFound")
        except Exception as e:
            resp = {"status":str(e), "data":None}
            print(f"readJSON: {str(e)}")
        return resp

# %%
test = {'name':'Arvind'}

# %%
test_dict = {}

# %%
test_dict.update(test)

# %%
print(test)

# %%
for i in test:
    print(i['n'])

# %%
empty_dict = {}
new_dict = {"key1": "value1", "key2": "value2"}
empty_dict.update(new_dict)
print(empty_dict)

# %%
second_dict = {'name':'Arvind'}

# %%
empty_dict.update(second_dict)

# %%
print(empty_dict)

# %%
test_dict = {}

data = [{"name" : "arvind"}, {"age": 28}, {"occupation":"SE"}]

for no,item in enumerate(data): 
    test_dict.update(item)
print(test_dict)

# %% [markdown]
# ## logging

# %% [markdown]
# working one

# %%
# imports
import logging

# %%
notebookName = 'testingNotebook'
logFileName  = notebookName + '.log'

# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Create a log format and set it to the file handler
log_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler and set the file name and logging level
file_handler = logging.FileHandler(logFileName)

# file_handler = logging.FileHandler('%S.log' % __file__)
#file_handler.setLevel(logging.INFO)

file_handler.setFormatter(log_format)

# Add the file handler to the logger
logger.addHandler(file_handler)

# %%
def div(firstNum: int, secondNum: int):
    logger.info('entering into div funtion')  
    try:
     
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.error('exeception occured :', exc_info=True)
        
    logger.info('exiting into div funtion')  
    
        
div(4,0)  

# Upload the log file to the S3 bucket
s3.upload_file(s3_file_name, s3_bucket_name, s3_file_name)

# %%
# !ls

# %%
# !cat testingNotebook.log

# %%
# !rm testingNotebook.log

# %% [markdown]
# =========================================================================

# %% [markdown]
# writing the log into a destination location -aws s3

# %%
# !pip install boto3

# %%
###############################
## version-1.2 of above script ## :: status : working - able to write the file into the s3 bucket under the folder python-logs.
###############################

# imports
import logging
import boto3


notebookName   = 'testingNotebook'
logFileName    = notebookName + '.log'

s3_bucket_name = "neu-data-analytics"
s3FolderName   = 'python-logs/'
s3filePath     =  s3FolderName + logFileName

# Set your AWS access key and secret access key
AWS_ACCESS_KEY_ID = "AKIAVMM664F75NS4NJOL"
AWS_SECRET_ACCESS_KEY = "g6quKLn02/Wco1du66mRatqiKrwq5C3EXbvjJ6Or"

# Create an S3 client object with your AWS credentials
s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY_ID, aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Create a log format and set it to the file handler
log_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler and set the file name and logging level
file_handler = logging.FileHandler(logFileName)

# file_handler = logging.FileHandler('%S.log' % __file__)
#file_handler.setLevel(logging.INFO)

file_handler.setFormatter(log_format)

# Add the file handler to the logger
logger.addHandler(file_handler)


def div(firstNum: int, secondNum: int):
    logger.info('entering into div funtion')  
    try:
     
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.error('exeception occured :', exc_info=True)
        
    logger.info('exiting into div funtion')  
    
        
div(4,0)  

# Upload the log file to the S3 bucket
s3.upload_file(logFileName, s3_bucket_name, s3filePath)

# %% [markdown]
# #### version-1.3 : saves the logs inthe subfolder with the name of the script. if the subfolder doesnt exists it creates one and inserts it into that.

# %%
# imports
import logging
import boto3


notebookName     = 'testingNotebook'
logFileName      = notebookName + '.log'

s3_bucket_name   = "neu-data-analytics"
s3RootFolderName = 'python-logs/'
s3FolderName     = notebookName + '_logs/'
s3filePath       =  s3RootFolderName + s3FolderName + logFileName

# Set your AWS access key and secret access key
AWS_ACCESS_KEY_ID = "AKIAVMM664F75NS4NJOL"
AWS_SECRET_ACCESS_KEY = "g6quKLn02/Wco1du66mRatqiKrwq5C3EXbvjJ6Or"

# Create an S3 client object with your AWS credentials
s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY_ID, aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Create a log format and set it to the file handler
log_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler and set the file name and logging level
file_handler = logging.FileHandler(logFileName)

# file_handler = logging.FileHandler('%S.log' % __file__)
#file_handler.setLevel(logging.INFO)

file_handler.setFormatter(log_format)

# Add the file handler to the logger
logger.addHandler(file_handler)


def div(firstNum: int, secondNum: int):
    logger.info('entering into div funtion')  
    try:
     
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.error('exeception occured :', exc_info=True)
        
    logger.info('exiting into div funtion')  
    
        
div(4,0)  

# Upload the log file to the S3 bucket
s3.upload_file(logFileName, s3_bucket_name, s3filePath)

# %% [markdown]
# #### version-1.4 : check if the log file already exists in the s3 then read the file and update it with new logs else create a new file.

# %%
# imports
import logging
import boto3


notebookName     = 'testingNotebook'
logFileName      = notebookName + '.log'


s3_bucket_name   = "neu-data-analytics"
s3RootFolderName = 'python-logs/'
s3FolderName     = notebookName + '_logs/'
s3filePath       =  s3RootFolderName + s3FolderName + logFileName


# Set your AWS access key and secret access key
AWS_ACCESS_KEY_ID = "AKIAVMM664F75NS4NJOL"
AWS_SECRET_ACCESS_KEY = "g6quKLn02/Wco1du66mRatqiKrwq5C3EXbvjJ6Or"


# Create an S3 client object with your AWS credentials
s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY_ID, aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Create a log format and set it to the file handler
log_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Create a file handler and set the file name and logging level
file_handler = logging.FileHandler(logFileName)

# file_handler = logging.FileHandler('%S.log' % __file__)
#file_handler.setLevel(logging.INFO)

file_handler.setFormatter(log_format)

# Add the file handler to the logger
logger.addHandler(file_handler)


def div(firstNum: int, secondNum: int):
    logger.info('entering into div funtion')  
    try:
     
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.error('exeception occured :', exc_info=True)
        
    logger.info('exiting from div funtion')  
    
        
div(4,0)  

# Upload the log file to the S3 bucket
s3.upload_file(logFileName, s3_bucket_name, s3filePath)

# %%
for i in help('modules'):
    if i = 'pyarrow'
    print('')

# %%
#updated code version : 1.3 : to handle same log entering multiple times, issue could be because of we are intializing a new logger every time we run the cell.

#installing missing package : boto3 - for connecting with s3, an aws python SDK. 
if help('modules') 

import os
import logging
import boto3

notebookName = 'testingNotebook'
logFileName = notebookName + '.log'

s3_bucket_name = "neu-data-analytics"
s3RootFolderName = 'python-logs/'
s3SubfolderFolderName = notebookName + '_logs/'
s3filePath = s3RootFolderName + s3SubfolderFolderName + logFileName

# Set your AWS access key and secret access key
AWS_ACCESS_KEY_ID = "AKIAVMM664F75NS4NJOL"
AWS_SECRET_ACCESS_KEY = "g6quKLn02/Wco1du66mRatqiKrwq5C3EXbvjJ6Or"

# Create an S3 client object with your AWS credentials
s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY_ID, aws_secret_access_key=AWS_SECRET_ACCESS_KEY)


# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Check if the file handler has already been added to the logger
if not logger.handlers:
    # Create a log format and set it to the file handler
    log_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

    # Create a file handler and set the file name and logging level
    if not os.path.exists(s3SubfolderFolderName):
        os.makedirs(s3SubfolderFolderName)
    file_handler = logging.FileHandler(os.path.join(s3SubfolderFolderName, logFileName))

    # file_handler = logging.FileHandler('%S.log' % __file__)
    # file_handler.setLevel(logging.INFO)

    file_handler.setFormatter(log_format)

    # Add the file handler to the logger
    logger.addHandler(file_handler)


def div(firstNum: int, secondNum: int):
    logger.info('entering into div function')
    try:

        if secondNum > firstNum:
            div_result = secondNum / firstNum
            return div_result

        if firstNum > secondNum:
            div_result = firstNum / secondNum
            return div_result

    except Exception as e:
        logger.error('exception occurred :', exc_info=True)

    logger.info('exiting from div function')


div(4, 0)

# Upload the log file to the S3 bucket
s3.upload_file(os.path.join(s3SubfolderFolderName, logFileName), s3_bucket_name, s3filePath)

# %%
import logging
import boto3

# Create an S3 client object
s3 = boto3.client('s3')

# Set the name of your S3 bucket and the file name you want to save
s3_bucket_name = 'neu-data-analytics/python-logs/'
s3_file_name = 'my_log_file.log'

# Check if the log file exists in S3
try:
    s3.head_object(Bucket=s3_bucket_name, Key=s3_file_name)
    # If the log file exists, download it and append the new logs to the end
    s3.download_file(s3_bucket_name, s3_file_name, s3_file_name)
    file_handler = logging.FileHandler(s3_file_name, mode='a')
except:
    # If the log file does not exist, create a new one
    file_handler = logging.FileHandler(s3_file_name, mode='w')

# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.INFO)

# Set the logging level of the file handler
file_handler.setLevel(logging.INFO)

# Create a log format and set it to the file handler
log_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(log_format)

# Add the file handler to the logger
logger.addHandler(file_handler)

# Write a log message
logger.info('This is a log message')

# Upload the log file to the S3 bucket
s3.upload_file(s3_file_name, s3_bucket_name, s3_file_name)

# %% [markdown]
# Testing space

# %%
import logging

notebookName = 'testingNotebook'
logFileName  = notebookName + '.log'

# Create a logger object and configure it
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# Create a file handler and set its level to DEBUG
file_handler = logging.FileHandler(logFileName)
file_handler.setLevel(logging.DEBUG)

# Create a formatter and add it to the file handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)

# Add the file handler to the logger
logger.addHandler(file_handler)

def div(firstNum: int, secondNum: int):
    try:          
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.exception('Exception occurred: %s', e)

div(4, 0)

# %%
import logging

# Create a logger object and configure it
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# Create a console handler and set its level to DEBUG
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)

# Create a formatter and add it to the console handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console_handler.setFormatter(formatter)

# Add the console handler to the logger
logger.addHandler(console_handler)

def div(firstNum: int, secondNum: int):
    try:          
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.error('Exception occurred: %s', e)

div(4, 0)

# %%
import logging

notebookName = 'testingNotebook'
logFileName  = notebookName + '.log'

# Create a logger object
logger = logging.getLogger(__name__)

# Set the logging level (optional, default is WARNING)
logger.setLevel(logging.DEBUG)

# Remove any existing file handlers
logger.handlers = [h for h in logger.handlers if not isinstance(h, logging.FileHandler)]

# Add a new stream handler to print logs to console
console_handler = logging.StreamHandler()
logger.addHandler(console_handler)

def div(firstNum: int, secondNum: int):
    try:
        if secondNum > firstNum:
            div_result = secondNum/firstNum 
            return div_result

        if firstNum > secondNum:
            div_result = firstNum/secondNum 
            return div_result
        
    except Exception as e:
        logger.exception('Exception occurred:')
        
div(4,0)
