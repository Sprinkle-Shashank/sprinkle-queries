# %%
import requests
import pandas as pd
import io
from sprinkleSdk import SprinkleSdk as sp

# %%
headers = {
  'Sprinkle-Org-Id': 'c28dd0a414744b8a8996965abdff1c76',
  'Sprinkle-API-Key': 'c77995e62ce846f89afe71b84efedba1',
  'Sprinkle-API-Secret': '162444cf9a504277a2fa8d131c5e5ae4'
}

# %%
host = 'https://console.sprinkledata.com/'
report_id = 'd4db7d5d0e7240d987b6c542c08588cc'

# %%
url = host + 'api/v2/reports/' + report_id + '/download'

# %%
url

# %%
response = requests.get(url, headers=headers)

# %%
df2 = pd.read_csv(io.StringIO(response.text),sep=',')

# %%
df2
