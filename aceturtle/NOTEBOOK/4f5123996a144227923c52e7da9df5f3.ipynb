# %%
import requests
import pandas as pd
import io

headers = {
  'Sprinkle-Org-Id': 'c28dd0a414744b8a8996965abdff1c76',
  'Sprinkle-API-Key': 'c77995e62ce846f89afe71b84efedba1',
  'Sprinkle-API-Secret': '162444cf9a504277a2fa8d131c5e5ae4'
}

host = 'https://console.sprinkledata.com/'
reports = {'Store_Sales_Report_YTD' : '6e6c70385baf46b6ad1018776ae1b01c',
          }

# %%
url = host + 'api/v2/explores/' + reports['Store_Sales_Report_YTD'] + '/download'
response = requests.get(url, headers=headers)
df1 = pd.read_csv(io.StringIO(response.text),sep=',')

# %%
df1

# %%
test=df1[df1['store code']=='All Stores']

# %%
test['total offline sales'])
