# %%
from sprinkleSdk import SprinkleSdk as sp

# %%
import pandas as pd

# %%
df_actual = sp.read_explore('ea25ef8c2af1472dbedd8ccf5067d51e')

# %%
df_new = sp.read_explore('7ce1e71394d643849b6f8aa4f5eaf3c2')

# %%
len(df_actual)

# %%
df_actual.describe()

# %%
df_actual.columns

# %%
df_actual.columns = ['name',
       'user_id',
       'phone',
       'calculated',
       'adjustment',
       'absolute_limit',
       'adjusted_limit',
       'outstanding_disbursed_amount',
       'unused_credit_limit',
       'approval_date',
       'last_repayment_date',
       'number_of_loans_disbursed',
       'credit_check',
       'loans_in_filter',
       'joining_date',
       'device_change',
       'mcoins_used',
       'mcoins_balance',
       'user_tire',
       'profession_type']

# %%
df_new.columns = ['full_name', 'user_id', 'mobile_number', 'cl',
       'credit_limit_adjustment', 'absolute_credit_limit', 'adjusted',
       'outstanding_disbursed_amount', 'unused_credit_limit',
       'approval_date', 'last_repayment_date', 'loans_disbursed_count',
       'credit_check_status', 'salary_status', 'number_of_loan_filtered',
       'graduation_date', 'joining_date', 'device_change_status',
       'mcoins_used', 'mcoins_balance', 'user_tier', 'prof_name']

# %%
df_new.prof_name.value_counts()

# %%
help('sprinkleSdk')
