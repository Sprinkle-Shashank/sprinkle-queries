# %%
import pandas as pd
import numpy as np
import requests
import json
import io
import ast
from sprinkleSdk import SprinkleSdk as sp

# %%
df = sp.read_explore('23f53481046b48a88325a6fc57488ddd')
df.head()

# %%
len(df.user)

# %%
HEADERS = {'content-type': 'application/json', 'Authorization':'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..xeQyZijRKIek5cVNEaQFCeGnjOJBoyBG7Nw9Mfg3h1s_gcKRiyqSHUmjh0hZpEiLYlbL7_hmK_RAXp3FCzxLkMp3Z2MqZNFKQ_Oc7gR7JaHhEP6cpBjygCxjgGX4D_GXNVJ-4OMVZbiCvChKtFcWeJZMP3ZRT4AGkQ-nROU1TKEOEfxlALj0-iQ6Rd4wXSUw-uY4PYUxLnxMv2354QaA_mXk_imPF_2R9QRYJrWhUNm5MhSl1FxtSdK3OiASgqN-D1gEHMab_QnpfwDQVwVpgRer0L7S5cmNTk0EROsJrWzSTTi3f5aqS0CKk1fqSDDIjK3X7-_Bkg42Gy708OgdOQ'}
df_tbl=pd.DataFrame()
for j in range(0,len(df.user),100000):
    for k in range(j,j+100000,500):
        list2=[]
        for i in range(k,k+500):
            if i<len(df.user):
                list2.append(eval('{"id" : ""+str(df.user[i])+""}'))
                data={"users" :list2}
        r = requests.get("https://api.mpkt.in/salaried/v1/profile/profile_details_all", data=json.dumps(data), headers=HEADERS)
        df_tbl=df_tbl.append(pd.DataFrame.from_dict(ast.literal_eval(str(r.json()['data']).replace('[','').replace(']','')),orient='index'))
    print(j)
df_tbl.info()

# %%
df_tbl.reset_index(inplace=True)
df_tbl.rename(columns = {'index':'user'}, inplace = True)
df_tbl.head()

# %%
sp.drop_table('salaried_user_metrics')
sp.create_or_update_table('salaried_user_metrics', df_tbl)

# %%
test_df = pd.DataFrame({"col1":["test11","test12"],"col2":["test21","test22"]})

# %%
test_df

# %%
sp.create_or_update_table('test_nb_tbl', test_df)
