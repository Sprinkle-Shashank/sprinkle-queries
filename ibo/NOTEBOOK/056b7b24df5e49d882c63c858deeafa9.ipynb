# %%
from sprinkleSdk import SprinkleSdk as sp
from datetime import datetime

#data = sp.readExplore('5cfe47a7e51341c393431c3c8d09cb7c')
#print(data)
#max_lastdate = data.iat[0,0]
#max_lastdate = datetime.strptime(max_lastdate, '%Y-%m-%d %H:%M:%S')

max_lastdate = '2021-01-01 00:00:00'

print(max_lastdate, type(max_lastdate))

# %%
url ='https://erp.ibo.com'
db = 'bvdeveloper-ebomart-production-2788402'
username = 'admin'
password = 'b6abad343cad2a0ac3aaad8197fa2aa41df32281'

# %%
import pandas as pd
import numpy as np
import xmlrpc.client
import time
from sprinkleSdk import SprinkleSdk as sp

# %%
common = xmlrpc.client.ServerProxy('{}/xmlrpc/2/common'.format(url))
common.version()

# %%
uid = common.authenticate(db, username, password, {})
uid

# %%
models = xmlrpc.client.ServerProxy('{}/xmlrpc/2/object'.format(url))

# %%
count=models.execute_kw(db, uid, password,
    'product.template', 'search_count',[[['id','!=','0']]])
count

# %%
Columns=models.execute_kw(
    db, uid, password, 'product.template', 'fields_get',
    [], {'attributes':['type']})
columns_list=dict.keys(Columns)
columns_list=list(columns_list)
print(columns_list)

# %%
columns_list=[
'standard_price',
'id',
'display_name',
'write_date',
'__last_update']

# %%
pip install pandas_gbq

# %%
import pandas as pd
import pandas_gbq
from google.oauth2 import service_account

# %%
credentials = service_account.Credentials.from_service_account_info(
    {
  "type": "service_account",
  "project_id": "ebo-sandbox",
  "private_key_id": "81929968a287ad78d57c3a7885fd665ec83135e2",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "sprinkle-analytics-poc@ebo-sandbox.iam.gserviceaccount.com",
  "client_id": "113738176372589161116",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/sprinkle-analytics-poc%40ebo-sandbox.iam.gserviceaccount.com"
},
)

# %%
print("block")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 0,'limit':10000}))
df.info()

# %%
#Iterating through columns to segregate object and and bool types
cast_col = []

cast_col.append('id')

for i in df:
    if str(df[i].dtype) == 'bool' or str(df[i].dtype) == 'object':
        cast_col.append(i)
        
print(cast_col)        
len(cast_col)

# %%
df[cast_col] = df[cast_col].astype(str)

# %%
pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='replace',)

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 10001,'limit':20000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 20001,'limit':30000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 30001,'limit':40000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 40001,'limit':50000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 50001,'limit':60000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 60001,'limit':70000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 70001,'limit':80000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 80001,'limit':90000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 90001,'limit':100000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 100001,'limit':110000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 110001,'limit':120000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 120001,'limit':130000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 130001,'limit':140000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 140001,'limit':150000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 150001,'limit':160000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 160001,'limit':170000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 170001,'limit':180000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 180001,'limit':190000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 190001,'limit':200000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 200001,'limit':210000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 210001,'limit':220000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 220001,'limit':230000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 230001,'limit':240000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 240001,'limit':250000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 250001,'limit':260000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 260001,'limit':270000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 270001,'limit':280000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 280001,'limit':290000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 290001,'limit':300000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 300001,'limit':310000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 310001,'limit':320000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 320001,'limit':330000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 330001,'limit':340000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 340001,'limit':360000}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("block s")
df=pd.DataFrame(models.execute_kw(db, uid, password,'product.template', 'search_read',[],{'fields': columns_list, 'offset': 360001,'limit':369951}))

df[cast_col] = df[cast_col].astype(str)

pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.product_template_raw', project_id="ebo-sandbox", credentials=credentials,if_exists='append',)
print("block e")

# %%
print("done")

# %%
from pytz import timezone
from datetime import datetime
rnow = datetime.now(timezone("Asia/Kolkata")).strftime('%Y-%m-%d %H:%M:%S.%f')
print("Last Updated - " + rnow + "\n" + "Rows added - " + str(count))
