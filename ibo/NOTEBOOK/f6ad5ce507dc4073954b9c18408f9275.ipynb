# %%
from sprinkleSdk import SprinkleSdk as sp

max_lastdate = '2021-01-01 00:00:00'

print(max_lastdate, type(max_lastdate))

# %%
url ='https://erp.ibo.com'
db = 'bvdeveloper-ebomart-production-2788402'
username = 'admin'
password = '837b1862d7079f86cd9750b2321cbfac6d9073aa'

# %%
import pandas as pd
import numpy as np
import xmlrpc.client
import time
from sprinkleSdk import SprinkleSdk as sp

# %%
common = xmlrpc.client.ServerProxy('{}/xmlrpc/2/common'.format(url))
common.version()

# %%
uid = common.authenticate(db, username, password, {})
uid

# %%
models = xmlrpc.client.ServerProxy('{}/xmlrpc/2/object'.format(url))

# %%
count=models.execute_kw(db, uid, password,
    'otb.limit', 'search_count',[[['id','!=','0']]])
count

# %%
Columns=models.execute_kw(
    db, uid, password, 'otb.limit', 'fields_get',
    [], {'attributes':['type']})
columns_list=dict.keys(Columns)
columns_list=list(columns_list)
print(columns_list)

# %%
columns_list=['name', 'product_categ', 'otb_amend_lines', 'otb_class_lines', 'from_date', 'to_date', 'balance_otb', 'budgeted_otb', 'utilized_otb', 'otb_limit', 'amend_otb_req', 'state', 'level_1_approved', 'reject_reason', 'l1_approval_submitted', 'account_branch', 'po_line_ids', 'po_line_history_ids', 'activity_ids', 'activity_state', 'activity_user_id', 'activity_type_id', 'activity_type_icon', 'activity_date_deadline', 'my_activity_date_deadline', 'activity_summary', 'activity_exception_decoration', 'activity_exception_icon', 'message_is_follower', 'message_follower_ids', 'message_partner_ids', 'message_channel_ids', 'message_ids', 'message_unread', 'message_unread_counter', 'message_needaction', 'message_needaction_counter', 'message_has_error', 'message_has_error_counter', 'message_attachment_count', 'message_main_attachment_id', 'website_message_ids', 'message_has_sms_error', 'id', 'display_name', 'create_uid', 'create_date', 'write_uid', 'write_date', '__last_update']

# %%
pip install pandas_gbq

# %%
import pandas as pd
import pandas_gbq
from google.oauth2 import service_account

# %%
credentials = service_account.Credentials.from_service_account_info(
    {
  "type": "service_account",
  "project_id": "ebo-sandbox",
  "private_key_id": "81929968a287ad78d57c3a7885fd665ec83135e2",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "sprinkle-analytics-poc@ebo-sandbox.iam.gserviceaccount.com",
  "client_id": "113738176372589161116",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/sprinkle-analytics-poc%40ebo-sandbox.iam.gserviceaccount.com"
},
)

# %%
print("block")
df=pd.DataFrame(models.execute_kw(db, uid, password,'otb.limit', 'search_read',[[['id','!=','0']]],{'fields': columns_list}))

# %%
df[['name', 'product_categ', 'otb_amend_lines', 'otb_class_lines', 'from_date', 'to_date', 'balance_otb', 'budgeted_otb', 'utilized_otb', 'otb_limit', 'amend_otb_req', 'state', 'level_1_approved', 'reject_reason', 'l1_approval_submitted', 'account_branch', 'po_line_ids', 'po_line_history_ids', 'activity_ids', 'activity_state', 'activity_user_id', 'activity_type_id', 'activity_type_icon', 'activity_date_deadline', 'my_activity_date_deadline', 'activity_summary', 'activity_exception_decoration', 'activity_exception_icon', 'message_is_follower', 'message_follower_ids', 'message_partner_ids', 'message_channel_ids', 'message_ids', 'message_unread', 'message_unread_counter', 'message_needaction', 'message_needaction_counter', 'message_has_error', 'message_has_error_counter', 'message_attachment_count', 'message_main_attachment_id', 'website_message_ids', 'message_has_sms_error', 'id', 'display_name', 'create_uid', 'create_date', 'write_uid', 'write_date', '__last_update']]=df[['name', 'product_categ', 'otb_amend_lines', 'otb_class_lines', 'from_date', 'to_date', 'balance_otb', 'budgeted_otb', 'utilized_otb', 'otb_limit', 'amend_otb_req', 'state', 'level_1_approved', 'reject_reason', 'l1_approval_submitted', 'account_branch', 'po_line_ids', 'po_line_history_ids', 'activity_ids', 'activity_state', 'activity_user_id', 'activity_type_id', 'activity_type_icon', 'activity_date_deadline', 'my_activity_date_deadline', 'activity_summary', 'activity_exception_decoration', 'activity_exception_icon', 'message_is_follower', 'message_follower_ids', 'message_partner_ids', 'message_channel_ids', 'message_ids', 'message_unread', 'message_unread_counter', 'message_needaction', 'message_needaction_counter', 'message_has_error', 'message_has_error_counter', 'message_attachment_count', 'message_main_attachment_id', 'website_message_ids', 'message_has_sms_error', 'id', 'display_name', 'create_uid', 'create_date', 'write_uid', 'write_date', '__last_update']].astype(str)

# %%
pandas_gbq.to_gbq(
    df, 'sprinkle_analytics_poc.xf', project_id="ebo-sandbox", credentials=credentials,if_exists='replace',)

# %%
print("done")

# %%
from pytz import timezone
from datetime import datetime
rnow = datetime.now(timezone("Asia/Kolkata")).strftime('%Y-%m-%d %H:%M:%S.%f')
print("Last Updated - " + rnow + "\n" + "Rows added - " + str(count))
